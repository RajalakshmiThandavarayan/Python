# %%
age=int(input("Enter the age:"))
if(age<18):
    print("Minor")
else:
    print("Adult")
# Out:
# Enter the age: 11
# Minor

# %%
if(age<10):
    print("Pediatric")
elif(age>10 and age <18):
    print("Minor")
else:
    print("Adult")
# Out:
# Minor

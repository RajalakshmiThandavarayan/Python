# %%
num1=10
num2=20
add = 30 + 20
print("The addition of two numbers")
print("The number 1 :",num1)
print("The number 2 :",num2)
print("The Answer:",add)
# Out:
# The addition of two numbers
# The number 1 : 10
# The number 2 : 20
# The Answer: 50

# %%
first_name = "Raji"

# %%
a=int(input("Enter the input a:"))
b=int(input("Enter the input b:"))
print("The Addition of a and b is :",a+b)
# Out:
# Enter the input a: 20
# Enter the input b: 30
# The Addition of a and b is : 50

# %%
class Multiplefunction():
    def OddEven():
        number=6
        if(number%2==0):
            return ('is Even number')
        else:
            return ('is Odd number')
    def Addition():
        a=100
        b=12
        print("Addtion :",a+b)
    def Subraction():
        a=100
        b=12
        print("Subraction :",a-b)
    def Multiplication():
        a=100
        b=12
        print("Multiplication :",a*b)

# %%
Multiplefunction.Subraction()
# Out:
# Subraction : 88

# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

#a = 10
#b = "5"
#print(a + b)

#unsupported operand type error
a=10
b="5"
print(a+int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?
#indentation issue
def add_numbers(a, b):
    return a + b
add_numbers(1,2)
# Out:
# 3

# %%
#4.Identify the bug in the following Python code:
#indentation and wrong index called inside print statement
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
#Brackets missing
#print "Hello, World!"
print("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
zero division error
x = 5 / 0

# %%
#7.Find the error in the following Python code:
#string concatenate error

#name="Alice"
#age = 25
#print("Name: " + name + ", Age: " + age)
name="Alice"
age = 25
print("Name: " + str(name) + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
# the start value must be grater than stop value if step value is in negative value
for i in range(1, 10, -1):
    print(i)

# %%
#9. Find the error in the following Python code:
#condtion having assigment operator instead of compare operator(==)
#x = 10
#if x = 5:
#    print("x is 5")

x = 10
if x == 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:
#colon is missing
def greet(name):
    print("Hello, " + name)

# %%
ord('A')
# Out:
# 65

# %%
print(list("hello"))
# Out:
# ['h', 'e', 'l', 'l', 'o']
